# %% [markdown]
# # SEGMENT 3 - S&P 500 TOP 5 Stocks

# %%
#initial imports
import pandas as pd
import glob
import os
import numpy as np
import datetime as dt

# %% [markdown]
# ## Getting familiar with the Crypto datasets

# %%
#list all crypto csv files only in directory
#taken from https://medium.com/@stella96joshua/how-to-combine-multiple-csv-files-using-python-for-your-analysis-a88017c6ff9e
file_list = glob.glob("../Data/Crypto/*.{}".format("csv"))
file_list
# Out:
# ['../Data/Crypto/stocks_data.csv',
#  '../Data/Crypto/crypto_data.csv',
#  '../Data/Crypto/ETH_data.csv',
#  '../Data/Crypto/BTC_data.csv',
#  '../Data/Crypto/DOGE_data.csv',
#  '../Data/Crypto/sp500_data.csv',
#  '../Data/Crypto/amazon_data.csv',
#  '../Data/Crypto/nvidia_data.csv',
#  '../Data/Crypto/apple_data.csv',
#  '../Data/Crypto/BNB_data.csv',
#  '../Data/Crypto/ethereum_data.csv',
#  '../Data/Crypto/ADA_data.csv',
#  '../Data/Crypto/microsoft_data.csv',
#  '../Data/Crypto/tesla_data.csv']

# %%
#appending a column for crypto names in new dataframe to later differentiate them all in the master file
ada = pd.read_csv("../Data/Crypto/ADA_data.csv")
ada["Name"] = "Cardano"
ada
# Out:
#               Date      Open      High       Low     Close  Adj Close  \
# 0     Dec 31, 2022  0.245577  0.251686  0.244431  0.246466   0.246466
# 1     Dec 30, 2022  0.244126  0.245987  0.240350  0.245557   0.245557
# 2     Dec 29, 2022  0.248380  0.248460  0.241094  0.244140   0.244140
# 3     Dec 28, 2022  0.260384  0.260842  0.247964  0.248378   0.248378
# 4     Dec 27, 2022  0.265306  0.265969  0.257486  0.260370   0.260370
# ...            ...       ...       ...       ...       ...        ...
# 1821  Jan 05, 2018  1.171150  1.252420  0.903503  0.999559   0.999559
# 1822  Jan 04, 2018  1.094030  1.327210  1.037650  1.114120   1.114120
# 1823  Jan 03, 2018  0.779681  1.085670  0.778578  1.079660   1.079660
# 1824  Jan 02, 2018  0.724676  0.794646  0.697856  0.782587   0.782587
# 1825  Jan 01, 2018  0.718847  0.730051  0.671941  0.728657   0.728657
#
#            Volume     Name
# 0     144,122,815  Cardano
# 1     159,952,057  Cardano
# 2     214,425,739  Cardano
# 3     209,596,269  Cardano
# 4     164,331,309  Cardano
# ...           ...      ...
# 1821  508,100,000  Cardano
# 1822  593,430,016  Cardano
# 1823  657,398,016  Cardano
# 1824  289,712,000  Cardano
# 1825  150,186,000  Cardano
#
# [1826 rows x 8 columns]

# %%
bnb = pd.read_csv("../Data/Crypto/BNB_data.csv")
bnb["Name"] = "Binance"
bnb
# Out:
#               Date    Open    High     Low   Close  Adj Close       Volume  \
# 0     Dec 31, 2022  245.79  247.58  245.11  246.35     246.35  307,551,853
# 1     Dec 30, 2022  246.46  246.50  243.13  245.78     245.78  342,300,809
# 2     Dec 29, 2022  244.17  246.60  243.58  246.48     246.48  345,312,528
# 3     Dec 28, 2022  246.61  246.84  242.11  244.14     244.14  414,698,978
# 4     Dec 27, 2022  244.20  247.68  242.56  246.60     246.60  391,342,277
# ...            ...     ...     ...     ...     ...        ...          ...
# 1821  Jan 05, 2018    9.15   16.72    9.09   14.92      14.92  341,504,992
# 1822  Jan 04, 2018    9.45    9.54    8.85    9.21       9.21  158,819,008
# 1823  Jan 03, 2018    8.77    9.58    8.53    9.54       9.54  108,852,000
# 1824  Jan 02, 2018    8.46    9.12    8.22    8.84       8.84  104,789,000
# 1825  Jan 01, 2018    8.63    8.70    7.96    8.41       8.41   66,422,800
#
#          Name
# 0     Binance
# 1     Binance
# 2     Binance
# 3     Binance
# 4     Binance
# ...       ...
# 1821  Binance
# 1822  Binance
# 1823  Binance
# 1824  Binance
# 1825  Binance
#
# [1826 rows x 8 columns]

# %%
btc = pd.read_csv("../Data/Crypto/BTC_data.csv")
btc["Name"] = "Bitcoin"
btc
# Out:
#            Date      Open      High       Low     Close  Adj Close  \
# 0     31-Dec-22  16603.67  16628.99  16517.52  16547.50   16547.50
# 1     30-Dec-22  16641.33  16643.43  16408.47  16602.59   16602.59
# 2     29-Dec-22  16552.32  16651.76  16508.68  16642.34   16642.34
# 3     28-Dec-22  16716.40  16768.17  16497.56  16552.57   16552.57
# 4     27-Dec-22  16919.29  16959.85  16642.07  16717.17   16717.17
# ...         ...       ...       ...       ...       ...        ...
# 1821  05-Jan-18  15477.20  17705.20  15202.80  17429.50   17429.50
# 1822  04-Jan-18  15270.70  15739.70  14522.20  15599.20   15599.20
# 1823  03-Jan-18  14978.20  15572.80  14844.50  15201.00   15201.00
# 1824  02-Jan-18  13625.00  15444.60  13163.60  14982.10   14982.10
# 1825  01-Jan-18  14112.20  14112.20  13154.70  13657.20   13657.20
#
#               Volume     Name
# 0     11,239,186,456  Bitcoin
# 1     15,929,162,910  Bitcoin
# 2     14,472,237,479  Bitcoin
# 3     17,005,713,920  Bitcoin
# 4     15,748,580,239  Bitcoin
# ...              ...      ...
# 1821  23,840,899,072  Bitcoin
# 1822  21,783,199,744  Bitcoin
# 1823  16,871,900,160  Bitcoin
# 1824  16,846,600,192  Bitcoin
# 1825  10,291,200,000  Bitcoin
#
# [1826 rows x 8 columns]

# %%
doge = pd.read_csv("../Data/Crypto/DOGE_data.csv")
doge["Name"] = "Dogecoin"
doge
# Out:
#               Date      Open      High       Low     Close  Adj Close  \
# 0     Dec 31, 2022  0.068394  0.071109  0.068162  0.070294   0.070294
# 1     Dec 30, 2022  0.071032  0.071308  0.066953  0.068404   0.068404
# 2     Dec 29, 2022  0.070380  0.071302  0.069771  0.071042   0.071042
# 3     Dec 28, 2022  0.073727  0.073821  0.070052  0.070381   0.070381
# 4     Dec 27, 2022  0.075763  0.076022  0.073131  0.073724   0.073724
# ...            ...       ...       ...       ...       ...        ...
# 1821  Jan 05, 2018  0.009660  0.012283  0.009589  0.012167   0.012167
# 1822  Jan 04, 2018  0.009346  0.010036  0.008768  0.009644   0.009644
# 1823  Jan 03, 2018  0.009088  0.009584  0.008882  0.009320   0.009320
# 1824  Jan 02, 2018  0.008873  0.009598  0.008551  0.009145   0.009145
# 1825  Jan 01, 2018  0.009031  0.009063  0.008101  0.008909   0.008909
#
#            Volume      Name
# 0     289,371,049  Dogecoin
# 1     419,889,739  Dogecoin
# 2     285,144,119  Dogecoin
# 3     496,350,491  Dogecoin
# 4     290,428,818  Dogecoin
# ...           ...       ...
# 1821  212,383,008  Dogecoin
# 1822  108,986,000  Dogecoin
# 1823   66,349,900  Dogecoin
# 1824   89,424,096  Dogecoin
# 1825   50,616,900  Dogecoin
#
# [1826 rows x 8 columns]

# %%
eth = pd.read_csv("../Data/Crypto/ETH_data.csv")
eth["Name"] = "Ethereum"
eth
# Out:
#               Date      Open      High       Low     Close Adj Close  \
# 0     Dec 31, 2022  1,199.36  1,205.09  1,194.20  1,196.77  1,196.77
# 1     Dec 30, 2022  1,201.57  1,202.03  1,187.46  1,199.23  1,199.23
# 2     Dec 29, 2022  1,190.01  1,204.14  1,188.36  1,201.60  1,201.60
# 3     Dec 28, 2022  1,212.74  1,213.13  1,185.70  1,189.99  1,189.99
# 4     Dec 27, 2022  1,226.99  1,230.42  1,205.90  1,212.79  1,212.79
# ...            ...       ...       ...       ...       ...       ...
# 1821  Jan 05, 2018    975.75  1,075.39    956.33    997.72    997.72
# 1822  Jan 04, 2018    961.71  1,045.08    946.09    980.92    980.92
# 1823  Jan 03, 2018    886.00    974.47    868.45    962.72    962.72
# 1824  Jan 02, 2018    772.35    914.83    772.35    884.44    884.44
# 1825  Jan 01, 2018    755.76    782.53    742.00    772.64    772.64
#
#              Volume      Name
# 0     3,018,513,333  Ethereum
# 1     4,055,668,253  Ethereum
# 2     4,132,233,940  Ethereum
# 3     4,991,669,631  Ethereum
# 4     4,091,530,737  Ethereum
# ...             ...       ...
# 1821  6,683,149,824  Ethereum
# 1822  6,502,859,776  Ethereum
# 1823  5,093,159,936  Ethereum
# 1824  5,783,349,760  Ethereum
# 1825  2,595,760,128  Ethereum
#
# [1826 rows x 8 columns]

# %%
#append all 5 crypto csvs into one master csv
crypto_df = pd.concat([ada,bnb,btc,doge,eth])
crypto_df
# Out:
#               Date      Open      High       Low     Close Adj Close  \
# 0     Dec 31, 2022  0.245577  0.251686  0.244431  0.246466  0.246466
# 1     Dec 30, 2022  0.244126  0.245987   0.24035  0.245557  0.245557
# 2     Dec 29, 2022   0.24838   0.24846  0.241094   0.24414   0.24414
# 3     Dec 28, 2022  0.260384  0.260842  0.247964  0.248378  0.248378
# 4     Dec 27, 2022  0.265306  0.265969  0.257486   0.26037   0.26037
# ...            ...       ...       ...       ...       ...       ...
# 1821  Jan 05, 2018    975.75  1,075.39    956.33    997.72    997.72
# 1822  Jan 04, 2018    961.71  1,045.08    946.09    980.92    980.92
# 1823  Jan 03, 2018    886.00    974.47    868.45    962.72    962.72
# 1824  Jan 02, 2018    772.35    914.83    772.35    884.44    884.44
# 1825  Jan 01, 2018    755.76    782.53    742.00    772.64    772.64
#
#              Volume      Name
# 0       144,122,815   Cardano
# 1       159,952,057   Cardano
# 2       214,425,739   Cardano
# 3       209,596,269   Cardano
# 4       164,331,309   Cardano
# ...             ...       ...
# 1821  6,683,149,824  Ethereum
# 1822  6,502,859,776  Ethereum
# 1823  5,093,159,936  Ethereum
# 1824  5,783,349,760  Ethereum
# 1825  2,595,760,128  Ethereum
#
# [9130 rows x 8 columns]

# %%
#check data types of cols in dataframe
crypto_df.dtypes
# Out:
# Date         object
# Open         object
# High         object
# Low          object
# Close        object
# Adj Close    object
# Volume       object
# Name         object
# dtype: object

# %%
#convert date column to datetime data type
crypto_df["Date"] = pd.to_datetime(crypto_df["Date"])

#convert open, high, low, close, adj close columns to float
cols = ["Open", "High", "Low", "Close", "Adj Close"]
crypto_df[cols] = crypto_df[cols].apply(pd.to_numeric, errors = "coerce")
crypto_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume               object
# Name                 object
# dtype: object

# %%
#renaming column Adj_Close
crypto_df = crypto_df.rename(columns = {
    "Adj Close" : "Adj_Close"})
crypto_df
# Out:
#            Date        Open        High         Low       Close   Adj_Close  \
# 0    2022-12-31    0.245577    0.251686    0.244431    0.246466    0.246466
# 1    2022-12-30    0.244126    0.245987    0.240350    0.245557    0.245557
# 2    2022-12-29    0.248380    0.248460    0.241094    0.244140    0.244140
# 3    2022-12-28    0.260384    0.260842    0.247964    0.248378    0.248378
# 4    2022-12-27    0.265306    0.265969    0.257486    0.260370    0.260370
# ...         ...         ...         ...         ...         ...         ...
# 1821 2018-01-05  975.750000         NaN  956.330000  997.720000  997.720000
# 1822 2018-01-04  961.710000         NaN  946.090000  980.920000  980.920000
# 1823 2018-01-03  886.000000  974.470000  868.450000  962.720000  962.720000
# 1824 2018-01-02  772.350000  914.830000  772.350000  884.440000  884.440000
# 1825 2018-01-01  755.760000  782.530000  742.000000  772.640000  772.640000
#
#              Volume      Name
# 0       144,122,815   Cardano
# 1       159,952,057   Cardano
# 2       214,425,739   Cardano
# 3       209,596,269   Cardano
# 4       164,331,309   Cardano
# ...             ...       ...
# 1821  6,683,149,824  Ethereum
# 1822  6,502,859,776  Ethereum
# 1823  5,093,159,936  Ethereum
# 1824  5,783,349,760  Ethereum
# 1825  2,595,760,128  Ethereum
#
# [9130 rows x 8 columns]

# %%
#quick description of all cryptos
crypto_df.groupby("Name").describe()
# Out:
#             Open                                                        \
#            count          mean           std          min          25%
# Name
# Binance   1826.0    150.890663    183.925657     4.530000    14.820000
# Bitcoin   1826.0  20339.679496  16990.993283  3236.270000  7686.925000
# Cardano   1826.0      0.498833      0.630367     0.023954     0.064931
# Dogecoin  1826.0      0.062388      0.099214     0.001540     0.002606
# Ethereum  1075.0    306.960130    196.462213    84.280000   170.795000
#
#                                                       High                ...  \
#                    50%           75%           max   count          mean  ...
# Name                                                                      ...
# Binance      27.470000    296.440000    676.320000  1826.0    155.907662  ...
# Bitcoin   10966.995000  33789.307500  67549.730000  1826.0  20839.385575  ...
# Cardano       0.160197      0.790227      2.966390  1826.0      0.519724  ...
# Dogecoin      0.003892      0.082460      0.687801  1826.0      0.066003  ...
# Ethereum    226.660000    395.790000    995.150000  1068.0    311.552294  ...
#
#                  Close               Adj_Close                              \
#                    75%           max     count          mean           std
# Name
# Binance     296.412500    675.680000    1826.0    150.989074    183.832094
# Bitcoin   33740.257500  67566.830000    1826.0  20338.668680  16986.017627
# Cardano       0.790289      2.968239    1826.0      0.498572      0.630455
# Dogecoin      0.082357      0.684777    1826.0      0.062432      0.099268
# Ethereum    395.862500    997.720000    1074.0    306.514069    196.073348
#
#
#                   min          25%           50%           75%           max
# Name
# Binance      4.530000    14.835000     27.455000    296.412500    675.680000
# Bitcoin   3236.760000  7682.072500  10960.590000  33740.257500  67566.830000
# Cardano      0.023961     0.064918      0.159863      0.790289      2.968239
# Dogecoin     0.001537     0.002607      0.003889      0.082357      0.684777
# Ethereum    84.310000   170.830000    226.660000    395.862500    997.720000
#
# [5 rows x 40 columns]

# %%
#export the master crypto file
crypto_df.to_csv("../Data/crypto_data.csv", index=False)

# %% [markdown]
# ## Getting familiar with the S&P 500 dataset - itemized stocks

# %%
#appending a column for S&P500 itemized stocks in new dataframe to later differentiate them all in the master file
amzn = pd.read_csv("../Data/Crypto/amazon_data.csv")
amzn["Name"] = "Amazon"
amzn
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2018-01-02  58.599998  59.500000  58.525501  59.450500  59.450500
# 1     2018-01-03  59.415001  60.274502  59.415001  60.209999  60.209999
# 2     2018-01-04  60.250000  60.793499  60.233002  60.479500  60.479500
# 3     2018-01-05  60.875500  61.457001  60.500000  61.457001  61.457001
# 4     2018-01-08  61.799999  62.653999  61.601501  62.343498  62.343498
# ...          ...        ...        ...        ...        ...        ...
# 1254  2022-12-23  83.250000  85.779999  82.930000  85.250000  85.250000
# 1255  2022-12-27  84.970001  85.349998  83.000000  83.040001  83.040001
# 1256  2022-12-28  82.800003  83.480003  81.690002  81.820000  81.820000
# 1257  2022-12-29  82.870003  84.550003  82.550003  84.180000  84.180000
# 1258  2022-12-30  83.120003  84.050003  82.470001  84.000000  84.000000
#
#         Volume    Name
# 0     53890000  Amazon
# 1     62176000  Amazon
# 2     60442000  Amazon
# 3     70894000  Amazon
# 4     85590000  Amazon
# ...        ...     ...
# 1254  57433700  Amazon
# 1255  57284000  Amazon
# 1256  58228600  Amazon
# 1257  54995900  Amazon
# 1258  62330000  Amazon
#
# [1259 rows x 8 columns]

# %%
appl = pd.read_csv("../Data/Crypto/apple_data.csv")
appl["Name"] = "Apple"
appl
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-01-02   42.540001   43.075001   42.314999   43.064999   40.950493
# 1     2018-01-03   43.132500   43.637501   42.990002   43.057499   40.943363
# 2     2018-01-04   43.134998   43.367500   43.020000   43.257500   41.133541
# 3     2018-01-05   43.360001   43.842499   43.262501   43.750000   41.601864
# 4     2018-01-08   43.587502   43.902500   43.482498   43.587502   41.447342
# ...          ...         ...         ...         ...         ...         ...
# 1254  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 1255  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 1256  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 1257  2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
# 1258  2022-12-30  128.410004  129.949997  127.430000  129.929993  129.929993
#
#          Volume   Name
# 0     102223600  Apple
# 1     118071600  Apple
# 2      89738400  Apple
# 3      94640000  Apple
# 4      82271200  Apple
# ...         ...    ...
# 1254   63814900  Apple
# 1255   69007800  Apple
# 1256   85438400  Apple
# 1257   75703700  Apple
# 1258   76960600  Apple
#
# [1259 rows x 8 columns]

# %%
msft = pd.read_csv("../Data/Crypto/microsoft_data.csv")
msft["Name"] = "Microsoft"
msft
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-01-02   86.129997   86.309998   85.500000   85.949997   80.940376
# 1     2018-01-03   86.059998   86.510002   85.970001   86.349998   81.317085
# 2     2018-01-04   86.589996   87.660004   86.570000   87.110001   82.032784
# 3     2018-01-05   87.660004   88.410004   87.430000   88.190002   83.049858
# 4     2018-01-08   88.199997   88.580002   87.599998   88.279999   83.134583
# ...          ...         ...         ...         ...         ...         ...
# 1254  2022-12-23  236.110001  238.869995  233.940002  238.729996  238.729996
# 1255  2022-12-27  238.699997  238.929993  235.830002  236.960007  236.960007
# 1256  2022-12-28  236.889999  239.720001  234.169998  234.529999  234.529999
# 1257  2022-12-29  235.649994  241.919998  235.649994  241.009995  241.009995
# 1258  2022-12-30  238.210007  239.960007  236.660004  239.820007  239.820007
#
#         Volume       Name
# 0     22483800  Microsoft
# 1     26061400  Microsoft
# 2     21912000  Microsoft
# 3     23407100  Microsoft
# 4     22113000  Microsoft
# ...        ...        ...
# 1254  21207000  Microsoft
# 1255  16688600  Microsoft
# 1256  17457100  Microsoft
# 1257  19770700  Microsoft
# 1258  21930800  Microsoft
#
# [1259 rows x 8 columns]

# %%
nvda = pd.read_csv("../Data/Crypto/nvidia_data.csv")
nvda["Name"] = "Nvidia"
nvda
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-01-02   48.945000   49.875000   48.625000   49.837502   49.334663
# 1     2018-01-03   51.025002   53.424999   50.937500   53.117500   52.581566
# 2     2018-01-04   53.939999   54.512501   53.172501   53.397499   52.858749
# 3     2018-01-05   53.547501   54.227501   52.770000   53.849998   53.306686
# 4     2018-01-08   55.099998   56.250000   54.645000   55.500000   54.940041
# ...          ...         ...         ...         ...         ...         ...
# 1254  2022-12-23  151.960007  153.389999  148.830002  152.059998  152.059998
# 1255  2022-12-27  150.740005  151.000000  140.559998  141.210007  141.210007
# 1256  2022-12-28  139.270004  142.619995  138.839996  140.360001  140.360001
# 1257  2022-12-29  144.020004  146.830002  142.270004  146.029999  146.029999
# 1258  2022-12-30  143.339996  146.289993  142.330002  146.139999  146.139999
#
#         Volume    Name
# 0     35561600  Nvidia
# 1     91470400  Nvidia
# 2     58326800  Nvidia
# 3     58012400  Nvidia
# 4     88121600  Nvidia
# ...        ...     ...
# 1254  34932600  Nvidia
# 1255  46490200  Nvidia
# 1256  35106600  Nvidia
# 1257  35492300  Nvidia
# 1258  31027300  Nvidia
#
# [1259 rows x 8 columns]

# %%
tsla = pd.read_csv("../Data/Crypto/tesla_data.csv")
tsla["Name"] = "Tesla"
tsla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-01-02   20.799999   21.474001   20.733334   21.368668   21.368668
# 1     2018-01-03   21.400000   21.683332   21.036667   21.150000   21.150000
# 2     2018-01-04   20.858000   21.236668   20.378668   20.974667   20.974667
# 3     2018-01-05   21.108000   21.149332   20.799999   21.105333   21.105333
# 4     2018-01-08   21.066668   22.468000   21.033333   22.427334   22.427334
# ...          ...         ...         ...         ...         ...         ...
# 1254  2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 1255  2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 1256  2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 1257  2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 1258  2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#          Volume   Name
# 0      65283000  Tesla
# 1      67822500  Tesla
# 2     149194500  Tesla
# 3      68868000  Tesla
# 4     147891000  Tesla
# ...         ...    ...
# 1254  166989700  Tesla
# 1255  208643400  Tesla
# 1256  221070500  Tesla
# 1257  221923300  Tesla
# 1258  157304500  Tesla
#
# [1259 rows x 8 columns]

# %%
#append all 5 crypto csvs into one master csv
stocks_df = pd.concat([amzn,appl,msft,nvda,tsla])
stocks_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-01-02   58.599998   59.500000   58.525501   59.450500   59.450500
# 1     2018-01-03   59.415001   60.274502   59.415001   60.209999   60.209999
# 2     2018-01-04   60.250000   60.793499   60.233002   60.479500   60.479500
# 3     2018-01-05   60.875500   61.457001   60.500000   61.457001   61.457001
# 4     2018-01-08   61.799999   62.653999   61.601501   62.343498   62.343498
# ...          ...         ...         ...         ...         ...         ...
# 1254  2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 1255  2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 1256  2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 1257  2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 1258  2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#          Volume    Name
# 0      53890000  Amazon
# 1      62176000  Amazon
# 2      60442000  Amazon
# 3      70894000  Amazon
# 4      85590000  Amazon
# ...         ...     ...
# 1254  166989700   Tesla
# 1255  208643400   Tesla
# 1256  221070500   Tesla
# 1257  221923300   Tesla
# 1258  157304500   Tesla
#
# [6295 rows x 8 columns]

# %%
#get the datatypes
stocks_df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# Name          object
# dtype: object

# %%
#convert date column to datetime data type
stocks_df["Date"] = pd.to_datetime(stocks_df["Date"])

#convert open, high, low, close, adj close columns to float
cols = ["Open", "High", "Low", "Close", "Adj Close"]

# %%
#quick description of all cryptos
stocks_df.groupby("Name").describe()
# Out:
#              Open                                                             \
#             count        mean         std        min         25%         50%
# Name
# Amazon     1259.0  119.895163   35.655449  58.599998   89.062252  107.970001
# Apple      1259.0   98.028503   46.302471  35.994999   50.956249   91.279999
# Microsoft  1259.0  193.842002   74.607851  86.059998  119.444999  200.419998
# Nvidia     1259.0  116.302530   73.028602  31.622499   56.205000   96.389999
# Tesla      1259.0  131.914480  118.024908  12.073333   21.060001   81.431999
#
#                                      High              ...   Adj Close  \
#                   75%         max   count        mean  ...         75%
# Name                                                   ...
# Amazon     158.343750  187.199997  1259.0  121.332617  ...  158.086998
# Apple      142.760002  182.630005  1259.0   99.217804  ...  142.167084
# Microsoft  256.119996  344.619995  1259.0  195.878133  ...  253.122558
# Nvidia     160.790000  335.170013  1259.0  118.553969  ...  161.308281
# Tesla      235.556671  411.470001  1259.0  134.953362  ...  236.125000
#
#                        Volume                                          \
#                   max   count          mean           std         min
# Name
# Amazon     186.570496  1259.0  8.655625e+07  4.068152e+07  17626000.0
# Apple      180.959732  1259.0  1.168805e+08  5.504465e+07  35195900.0
# Microsoft  339.924805  1259.0  3.021664e+07  1.287278e+07   8989200.0
# Nvidia     333.407410  1259.0  4.775070e+07  2.241042e+07   9788400.0
# Tesla      409.970001  1259.0  1.324326e+08  9.017618e+07  29401800.0
#
#
#                   25%          50%          75%          max
# Name
# Amazon     58938000.0   74996000.0  102548000.0  311346000.0
# Apple      80142450.0  102300200.0  137205200.0  426510000.0
# Microsoft  22168000.0   27000600.0   34341000.0  111242100.0
# Nvidia     31861800.0   44092000.0   59008800.0  251152800.0
# Tesla      75780000.0  101611500.0  154391100.0  914082000.0
#
# [5 rows x 48 columns]

# %%
#convert date column to datetime data type
stocks_df["Date"] = pd.to_datetime(stocks_df["Date"])
stocks_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-01-02   58.599998   59.500000   58.525501   59.450500   59.450500
# 1    2018-01-03   59.415001   60.274502   59.415001   60.209999   60.209999
# 2    2018-01-04   60.250000   60.793499   60.233002   60.479500   60.479500
# 3    2018-01-05   60.875500   61.457001   60.500000   61.457001   61.457001
# 4    2018-01-08   61.799999   62.653999   61.601501   62.343498   62.343498
# ...         ...         ...         ...         ...         ...         ...
# 1254 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 1255 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 1256 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 1257 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 1258 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#          Volume    Name
# 0      53890000  Amazon
# 1      62176000  Amazon
# 2      60442000  Amazon
# 3      70894000  Amazon
# 4      85590000  Amazon
# ...         ...     ...
# 1254  166989700   Tesla
# 1255  208643400   Tesla
# 1256  221070500   Tesla
# 1257  221923300   Tesla
# 1258  157304500   Tesla
#
# [6295 rows x 8 columns]

# %%
#no need for this part of code
#stocks_df[cols] = stocks_df[cols].apply(pd.to_numeric, errors = "coerce")
#stocks_df.dtypes

# %%
#renaming Adj Close col to Adj_Close (for database naming reasons)
stocks_df = stocks_df.rename(columns = {
    "Adj Close" : "Adj_Close" 
})
stocks_df
# Out:
#            Date        Open        High         Low       Close   Adj_Close  \
# 0    2018-01-02   58.599998   59.500000   58.525501   59.450500   59.450500
# 1    2018-01-03   59.415001   60.274502   59.415001   60.209999   60.209999
# 2    2018-01-04   60.250000   60.793499   60.233002   60.479500   60.479500
# 3    2018-01-05   60.875500   61.457001   60.500000   61.457001   61.457001
# 4    2018-01-08   61.799999   62.653999   61.601501   62.343498   62.343498
# ...         ...         ...         ...         ...         ...         ...
# 1254 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 1255 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 1256 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 1257 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 1258 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#          Volume    Name
# 0      53890000  Amazon
# 1      62176000  Amazon
# 2      60442000  Amazon
# 3      70894000  Amazon
# 4      85590000  Amazon
# ...         ...     ...
# 1254  166989700   Tesla
# 1255  208643400   Tesla
# 1256  221070500   Tesla
# 1257  221923300   Tesla
# 1258  157304500   Tesla
#
# [6295 rows x 8 columns]

# %%
#check if Date col's datatype has indeed been changed to datetime format
stocks_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj_Close           float64
# Volume                int64
# Name                 object
# dtype: object

# %%
#quick description of the dataset
stocks_df.describe()
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  6295.000000  6295.000000  6295.000000  6295.000000  6295.000000
# mean    131.996535   133.987177   129.856104   131.970584   130.913395
# std      81.974339    83.354606    80.412275    81.896100    81.677952
# min      12.073333    12.445333    11.799333    11.931333    11.931333
# 25%      63.136250    64.413749    62.245001    63.320250    62.773216
# 50%     122.599998   124.480003   120.570000   122.540001   121.481689
# 75%     173.344254   175.290001   170.952499   173.173004   172.528045
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  6.295000e+03
# mean   8.276734e+07
# std    6.497641e+07
# min    8.989200e+06
# 25%    3.866435e+07
# 50%    6.774080e+07
# 75%    1.033050e+08
# max    9.140820e+08

# %%
#export as cleaned CSV
stocks_df.to_csv("../Data/stocks_data.csv", index = False)

# %% [markdown]
# #### Some initial visualizations of the datasets

# %%
#importing libraries for charts and vizualizations of both dataframes
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#some exploratory work & viz using the datasets

#ADA & DOGE COINS
fig, ax = plt.subplots()

ax.plot(ada["Close"], label = "ADA Close")
ax.plot(doge["Close"], label = "DOGE Close")
leg = ax.legend()

# %%
#some exploratory work & viz using the datasets

#AAPL & NVIDIA 

fig, ax = plt.subplots()
ax.plot(ada["Close"], label = "AAPL Close")
ax.plot(doge["Close"], label = "NVDA Close")
leg = ax.legend()
