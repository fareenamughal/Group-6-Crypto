# %% [markdown]
# # SEGMENT 1

# %%
#initial imports
import pandas as pd
import glob
import os
import numpy as np
import datetime as dt

# %% [markdown]
# ## Getting familiar with the Crypto datasets

# %%
#list all crypto csv files only in directory
#taken from https://medium.com/@stella96joshua/how-to-combine-multiple-csv-files-using-python-for-your-analysis-a88017c6ff9e
file_list = glob.glob("..\Data\Crypto\*.{}".format("csv"))
file_list
# Out:
# ['..\\Data\\Crypto\\ADA_data.csv',
#  '..\\Data\\Crypto\\BNB_data.csv',
#  '..\\Data\\Crypto\\BTC_data.csv',
#  '..\\Data\\Crypto\\DOGE_data.csv',
#  '..\\Data\\Crypto\\ETH_data.csv']

# %%
#appending a column for crypto names in new dataframe to later differentiate them all in the master file
ada = pd.read_csv("..\Data\Crypto\ADA_data.csv")
ada["Name"] = "Cardano"
ada
# Out:
#               Date      Open      High       Low     Close  Adj Close  \
# 0     Dec 31, 2022  0.245577  0.251686  0.244431  0.246466   0.246466
# 1     Dec 30, 2022  0.244126  0.245987  0.240350  0.245557   0.245557
# 2     Dec 29, 2022  0.248380  0.248460  0.241094  0.244140   0.244140
# 3     Dec 28, 2022  0.260384  0.260842  0.247964  0.248378   0.248378
# 4     Dec 27, 2022  0.265306  0.265969  0.257486  0.260370   0.260370
# ...            ...       ...       ...       ...       ...        ...
# 1821  Jan 05, 2018  1.171150  1.252420  0.903503  0.999559   0.999559
# 1822  Jan 04, 2018  1.094030  1.327210  1.037650  1.114120   1.114120
# 1823  Jan 03, 2018  0.779681  1.085670  0.778578  1.079660   1.079660
# 1824  Jan 02, 2018  0.724676  0.794646  0.697856  0.782587   0.782587
# 1825  Jan 01, 2018  0.718847  0.730051  0.671941  0.728657   0.728657
#
#            Volume     Name
# 0     144,122,815  Cardano
# 1     159,952,057  Cardano
# 2     214,425,739  Cardano
# ...

# %%
bnb = pd.read_csv("..\Data\Crypto\BNB_data.csv")
bnb["Name"] = "Binance"
bnb
# Out:
#               Date    Open    High     Low   Close  Adj Close       Volume  \
# 0     Dec 31, 2022  245.79  247.58  245.11  246.35     246.35  307,551,853
# 1     Dec 30, 2022  246.46  246.50  243.13  245.78     245.78  342,300,809
# 2     Dec 29, 2022  244.17  246.60  243.58  246.48     246.48  345,312,528
# 3     Dec 28, 2022  246.61  246.84  242.11  244.14     244.14  414,698,978
# 4     Dec 27, 2022  244.20  247.68  242.56  246.60     246.60  391,342,277
# ...            ...     ...     ...     ...     ...        ...          ...
# 1821  Jan 05, 2018    9.15   16.72    9.09   14.92      14.92  341,504,992
# 1822  Jan 04, 2018    9.45    9.54    8.85    9.21       9.21  158,819,008
# 1823  Jan 03, 2018    8.77    9.58    8.53    9.54       9.54  108,852,000
# 1824  Jan 02, 2018    8.46    9.12    8.22    8.84       8.84  104,789,000
# 1825  Jan 01, 2018    8.63    8.70    7.96    8.41       8.41   66,422,800
#
#          Name
# 0     Binance
# 1     Binance
# 2     Binance
# ...

# %%
btc = pd.read_csv("..\Data\Crypto\BTC_data.csv")
btc["Name"] = "Bitcoin"
btc
# Out:
#            Date      Open      High       Low     Close  Adj Close  \
# 0     31-Dec-22  16603.67  16628.99  16517.52  16547.50   16547.50
# 1     30-Dec-22  16641.33  16643.43  16408.47  16602.59   16602.59
# 2     29-Dec-22  16552.32  16651.76  16508.68  16642.34   16642.34
# 3     28-Dec-22  16716.40  16768.17  16497.56  16552.57   16552.57
# 4     27-Dec-22  16919.29  16959.85  16642.07  16717.17   16717.17
# ...         ...       ...       ...       ...       ...        ...
# 1821  05-Jan-18  15477.20  17705.20  15202.80  17429.50   17429.50
# 1822  04-Jan-18  15270.70  15739.70  14522.20  15599.20   15599.20
# 1823  03-Jan-18  14978.20  15572.80  14844.50  15201.00   15201.00
# 1824  02-Jan-18  13625.00  15444.60  13163.60  14982.10   14982.10
# 1825  01-Jan-18  14112.20  14112.20  13154.70  13657.20   13657.20
#
#               Volume     Name
# 0     11,239,186,456  Bitcoin
# 1     15,929,162,910  Bitcoin
# 2     14,472,237,479  Bitcoin
# 3     17,005,713,920  Bitcoin
# ...

# %%
doge = pd.read_csv("..\Data\Crypto\DOGE_data.csv")
doge["Name"] = "Dogecoin"
doge
# Out:
#               Date      Open      High       Low     Close  Adj Close  \
# 0     Dec 31, 2022  0.068394  0.071109  0.068162  0.070294   0.070294
# 1     Dec 30, 2022  0.071032  0.071308  0.066953  0.068404   0.068404
# 2     Dec 29, 2022  0.070380  0.071302  0.069771  0.071042   0.071042
# 3     Dec 28, 2022  0.073727  0.073821  0.070052  0.070381   0.070381
# 4     Dec 27, 2022  0.075763  0.076022  0.073131  0.073724   0.073724
# ...            ...       ...       ...       ...       ...        ...
# 1821  Jan 05, 2018  0.009660  0.012283  0.009589  0.012167   0.012167
# 1822  Jan 04, 2018  0.009346  0.010036  0.008768  0.009644   0.009644
# 1823  Jan 03, 2018  0.009088  0.009584  0.008882  0.009320   0.009320
# 1824  Jan 02, 2018  0.008873  0.009598  0.008551  0.009145   0.009145
# 1825  Jan 01, 2018  0.009031  0.009063  0.008101  0.008909   0.008909
#
#            Volume      Name
# 0     289,371,049  Dogecoin
# 1     419,889,739  Dogecoin
# 2     285,144,119  Dogecoin
# ...

# %%
eth = pd.read_csv("..\Data\Crypto\ETH_data.csv")
eth["Name"] = "Ethereum"
eth
# Out:
#               Date      Open      High       Low     Close Adj Close  \
# 0     Dec 31, 2022  1,199.36  1,205.09  1,194.20  1,196.77  1,196.77
# 1     Dec 30, 2022  1,201.57  1,202.03  1,187.46  1,199.23  1,199.23
# 2     Dec 29, 2022  1,190.01  1,204.14  1,188.36  1,201.60  1,201.60
# 3     Dec 28, 2022  1,212.74  1,213.13  1,185.70  1,189.99  1,189.99
# 4     Dec 27, 2022  1,226.99  1,230.42  1,205.90  1,212.79  1,212.79
# ...            ...       ...       ...       ...       ...       ...
# 1821  Jan 05, 2018    975.75  1,075.39    956.33    997.72    997.72
# 1822  Jan 04, 2018    961.71  1,045.08    946.09    980.92    980.92
# 1823  Jan 03, 2018    886.00    974.47    868.45    962.72    962.72
# 1824  Jan 02, 2018    772.35    914.83    772.35    884.44    884.44
# 1825  Jan 01, 2018    755.76    782.53    742.00    772.64    772.64
#
#              Volume      Name
# 0     3,018,513,333  Ethereum
# 1     4,055,668,253  Ethereum
# 2     4,132,233,940  Ethereum
# ...

# %%
#append all 5 crypto csvs into one master csv
crypto_df = pd.concat([ada,bnb,btc,doge,eth])
crypto_df
# Out:
#               Date      Open      High       Low     Close Adj Close  \
# 0     Dec 31, 2022  0.245577  0.251686  0.244431  0.246466  0.246466
# 1     Dec 30, 2022  0.244126  0.245987   0.24035  0.245557  0.245557
# 2     Dec 29, 2022   0.24838   0.24846  0.241094   0.24414   0.24414
# 3     Dec 28, 2022  0.260384  0.260842  0.247964  0.248378  0.248378
# 4     Dec 27, 2022  0.265306  0.265969  0.257486   0.26037   0.26037
# ...            ...       ...       ...       ...       ...       ...
# 1821  Jan 05, 2018    975.75  1,075.39    956.33    997.72    997.72
# 1822  Jan 04, 2018    961.71  1,045.08    946.09    980.92    980.92
# 1823  Jan 03, 2018    886.00    974.47    868.45    962.72    962.72
# 1824  Jan 02, 2018    772.35    914.83    772.35    884.44    884.44
# 1825  Jan 01, 2018    755.76    782.53    742.00    772.64    772.64
#
#              Volume      Name
# 0       144,122,815   Cardano
# 1       159,952,057   Cardano
# 2       214,425,739   Cardano
# ...

# %%
#check data types of cols in dataframe
crypto_df.dtypes
# Out:
# Date         object
# Open         object
# High         object
# Low          object
# Close        object
# Adj Close    object
# Volume       object
# Name         object
# dtype: object

# %%
#convert date column to datetime data type
crypto_df["Date"] = pd.to_datetime(crypto_df["Date"])

#convert open, high, low, close, adj close columns to float
cols = ["Open", "High", "Low", "Close", "Adj Close"]
crypto_df[cols] = crypto_df[cols].apply(pd.to_numeric, errors = "coerce")
crypto_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume               object
# Name                 object
# dtype: object

# %%
#renaming column Adj_Close
crypto_df = crypto_df.rename(columns = {
    "Adj Close" : "Adj_Close"})
crypto_df
# Out:
#            Date        Open        High         Low       Close   Adj_Close  \
# 0    2022-12-31    0.245577    0.251686    0.244431    0.246466    0.246466
# 1    2022-12-30    0.244126    0.245987    0.240350    0.245557    0.245557
# 2    2022-12-29    0.248380    0.248460    0.241094    0.244140    0.244140
# 3    2022-12-28    0.260384    0.260842    0.247964    0.248378    0.248378
# 4    2022-12-27    0.265306    0.265969    0.257486    0.260370    0.260370
# ...         ...         ...         ...         ...         ...         ...
# 1821 2018-01-05  975.750000         NaN  956.330000  997.720000  997.720000
# 1822 2018-01-04  961.710000         NaN  946.090000  980.920000  980.920000
# 1823 2018-01-03  886.000000  974.470000  868.450000  962.720000  962.720000
# 1824 2018-01-02  772.350000  914.830000  772.350000  884.440000  884.440000
# 1825 2018-01-01  755.760000  782.530000  742.000000  772.640000  772.640000
#
#              Volume      Name
# ...

# %%
#quick description of all cryptos
crypto_df.groupby("Name").describe()
# Out:
#             Open                                                        \
#            count          mean           std          min          25%
# Name
# Binance   1826.0    150.890663    183.925657     4.530000    14.820000
# Bitcoin   1826.0  20339.679496  16990.993283  3236.270000  7686.925000
# Cardano   1826.0      0.498833      0.630367     0.023954     0.064931
# Dogecoin  1826.0      0.062388      0.099214     0.001540     0.002606
# Ethereum  1075.0    306.960130    196.462213    84.280000   170.795000
#
#                                                       High                ...  \
#                    50%           75%           max   count          mean  ...
# Name                                                                      ...
# Binance      27.470000    296.440000    676.320000  1826.0    155.907662  ...
# Bitcoin   10966.995000  33789.307500  67549.730000  1826.0  20839.385575  ...
# ...

# %%
#export the master crypto file
crypto_df.to_csv("..\Data\crypto_data.csv", index=False)

# %% [markdown]
# ## Getting familiar with the S&P 500 dataset

# %%
#get snapshot of s&p500 dataset
sp500_df = pd.read_csv("..\Data\sp500_data.csv")
sp500_df
# Out:
#            Date     Open     High      Low    Close  Adj Close         Volume
# 0     30-Dec-22  3829.06  3839.85  3800.34  3839.50    3839.50  2,979,870,000
# 1     29-Dec-22  3805.45  3858.19  3805.45  3849.28    3849.28  3,003,680,000
# 2     28-Dec-22  3829.56  3848.32  3780.78  3783.22    3783.22  3,083,520,000
# 3     27-Dec-22  3843.34  3846.65  3813.22  3829.25    3829.25  3,030,300,000
# 4     23-Dec-22  3815.11  3845.80  3797.01  3844.82    3844.82  2,819,280,000
# ...         ...      ...      ...      ...      ...        ...            ...
# 1254  08-Jan-18  2742.67  2748.51  2737.60  2747.71    2747.71  3,246,160,000
# 1255  05-Jan-18  2731.33  2743.45  2727.92  2743.15    2743.15  3,239,280,000
# 1256  04-Jan-18  2719.31  2729.29  2719.07  2723.99    2723.99  3,697,340,000
# 1257  03-Jan-18  2697.85  2714.37  2697.77  2713.06    2713.06  3,544,030,000
# 1258  02-Jan-18  2683.73  2695.89  2682.36  2695.81    2695.81  3,397,430,000
#
# [1259 rows x 7 columns]

# %%
#get the datatypes
sp500_df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume        object
# dtype: object

# %%
#appending stock name column to standardize with crypto csv
sp500_df["Name"] = "S&P500"
sp500_df
# Out:
#            Date     Open     High      Low    Close  Adj Close         Volume  \
# 0     30-Dec-22  3829.06  3839.85  3800.34  3839.50    3839.50  2,979,870,000
# 1     29-Dec-22  3805.45  3858.19  3805.45  3849.28    3849.28  3,003,680,000
# 2     28-Dec-22  3829.56  3848.32  3780.78  3783.22    3783.22  3,083,520,000
# 3     27-Dec-22  3843.34  3846.65  3813.22  3829.25    3829.25  3,030,300,000
# 4     23-Dec-22  3815.11  3845.80  3797.01  3844.82    3844.82  2,819,280,000
# ...         ...      ...      ...      ...      ...        ...            ...
# 1254  08-Jan-18  2742.67  2748.51  2737.60  2747.71    2747.71  3,246,160,000
# 1255  05-Jan-18  2731.33  2743.45  2727.92  2743.15    2743.15  3,239,280,000
# 1256  04-Jan-18  2719.31  2729.29  2719.07  2723.99    2723.99  3,697,340,000
# 1257  03-Jan-18  2697.85  2714.37  2697.77  2713.06    2713.06  3,544,030,000
# 1258  02-Jan-18  2683.73  2695.89  2682.36  2695.81    2695.81  3,397,430,000
#
#         Name
# 0     S&P500
# ...

# %%
#convert date column to datetime data type
sp500_df["Date"] = pd.to_datetime(sp500_df["Date"])
sp500_df
# Out:
#            Date     Open     High      Low    Close  Adj Close         Volume  \
# 0    2022-12-30  3829.06  3839.85  3800.34  3839.50    3839.50  2,979,870,000
# 1    2022-12-29  3805.45  3858.19  3805.45  3849.28    3849.28  3,003,680,000
# 2    2022-12-28  3829.56  3848.32  3780.78  3783.22    3783.22  3,083,520,000
# 3    2022-12-27  3843.34  3846.65  3813.22  3829.25    3829.25  3,030,300,000
# 4    2022-12-23  3815.11  3845.80  3797.01  3844.82    3844.82  2,819,280,000
# ...         ...      ...      ...      ...      ...        ...            ...
# 1254 2018-01-08  2742.67  2748.51  2737.60  2747.71    2747.71  3,246,160,000
# 1255 2018-01-05  2731.33  2743.45  2727.92  2743.15    2743.15  3,239,280,000
# 1256 2018-01-04  2719.31  2729.29  2719.07  2723.99    2723.99  3,697,340,000
# 1257 2018-01-03  2697.85  2714.37  2697.77  2713.06    2713.06  3,544,030,000
# 1258 2018-01-02  2683.73  2695.89  2682.36  2695.81    2695.81  3,397,430,000
#
#         Name
# 0     S&P500
# ...

# %%
#no need for this part of code
#sp500_df[cols] = sp500_df[cols].apply(pd.to_numeric, errors = "coerce")
#sp500_df.dtypes

# %%
#renaming Adj Close col to Adj_Close (for database naming reasons)
sp500_df = sp500_df.rename(columns = {
    "Adj Close" : "Adj_Close" 
})
sp500_df
# Out:
#            Date     Open     High      Low    Close  Adj_Close         Volume  \
# 0    2022-12-30  3829.06  3839.85  3800.34  3839.50    3839.50  2,979,870,000
# 1    2022-12-29  3805.45  3858.19  3805.45  3849.28    3849.28  3,003,680,000
# 2    2022-12-28  3829.56  3848.32  3780.78  3783.22    3783.22  3,083,520,000
# 3    2022-12-27  3843.34  3846.65  3813.22  3829.25    3829.25  3,030,300,000
# 4    2022-12-23  3815.11  3845.80  3797.01  3844.82    3844.82  2,819,280,000
# ...         ...      ...      ...      ...      ...        ...            ...
# 1254 2018-01-08  2742.67  2748.51  2737.60  2747.71    2747.71  3,246,160,000
# 1255 2018-01-05  2731.33  2743.45  2727.92  2743.15    2743.15  3,239,280,000
# 1256 2018-01-04  2719.31  2729.29  2719.07  2723.99    2723.99  3,697,340,000
# 1257 2018-01-03  2697.85  2714.37  2697.77  2713.06    2713.06  3,544,030,000
# 1258 2018-01-02  2683.73  2695.89  2682.36  2695.81    2695.81  3,397,430,000
#
#         Name
# 0     S&P500
# ...

# %%
#check if Date col's datatype has indeed been changed to datetime format
sp500_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj_Close           float64
# Volume               object
# Name                 object
# dtype: object

# %%
#quick description of the dataset
sp500_df.describe()
# Out:
#               Open         High          Low        Close    Adj_Close
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   3449.673415  3470.866060  3426.301168  3449.724766  3449.724766
# std     668.795604   672.278346   665.154072   668.903627   668.903627
# min    2290.710000  2300.730000  2191.860000  2237.400000  2237.400000
# 25%    2842.390000  2857.675000  2825.450000  2844.115000  2844.115000
# 50%    3280.610000  3288.130000  3253.220000  3276.020000  3276.020000
# 75%    4038.645000  4077.880000  3995.845000  4028.935000  4028.935000
# max    4804.510000  4818.620000  4780.040000  4796.560000  4796.560000

# %%
#export as cleaned CSV
sp500_df.to_csv("..\Data\sp500_data-cleaned.csv", index = False)

# %% [markdown]
# #### Some initial visualizations of the datasets

# %%
#importing libraries for charts and vizualizations of both dataframes
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#some exploratory work & viz using the datasets

#ADA & DOGE COINS
fig, ax = plt.subplots()

ax.plot(ada["Close"], label = "ADA Close")
ax.plot(doge["Close"], label = "DOGE Close")
leg = ax.legend()

# %%
#ax1 = sp500_df.plot.bar(x="Date", y = "Close")
#sp500_df.groupby("Date").case_status.value_counts().unstack().plot.barh()

# %% [markdown]
# # Segment 2

# %% [markdown]
# ## Using S&P 500 dataset to train, test, split our ML (time series) model

# %%
#read the cleaned S&P 500 data
sp500cleaned_df = pd.read_csv("..\Data\sp500_data-cleaned.csv")
sp500cleaned_df
# Out:
#             Date     Open     High      Low    Close  Adj_Close  \
# 0     2022-12-30  3829.06  3839.85  3800.34  3839.50    3839.50
# 1     2022-12-29  3805.45  3858.19  3805.45  3849.28    3849.28
# 2     2022-12-28  3829.56  3848.32  3780.78  3783.22    3783.22
# 3     2022-12-27  3843.34  3846.65  3813.22  3829.25    3829.25
# 4     2022-12-23  3815.11  3845.80  3797.01  3844.82    3844.82
# ...          ...      ...      ...      ...      ...        ...
# 1254  2018-01-08  2742.67  2748.51  2737.60  2747.71    2747.71
# 1255  2018-01-05  2731.33  2743.45  2727.92  2743.15    2743.15
# 1256  2018-01-04  2719.31  2729.29  2719.07  2723.99    2723.99
# 1257  2018-01-03  2697.85  2714.37  2697.77  2713.06    2713.06
# 1258  2018-01-02  2683.73  2695.89  2682.36  2695.81    2695.81
#
#              Volume    Name
# 0     2,979,870,000  S&P500
# 1     3,003,680,000  S&P500
# 2     3,083,520,000  S&P500
# 3     3,030,300,000  S&P500
# 4     2,819,280,000  S&P500
# ...

# %%
#just making sure there are no empty rows in case later we run into problems
#we have the same number of rows as original dataset, we are good to go
sp500cleaned_df.dropna()
# Out:
#             Date     Open     High      Low    Close  Adj_Close  \
# 0     2022-12-30  3829.06  3839.85  3800.34  3839.50    3839.50
# 1     2022-12-29  3805.45  3858.19  3805.45  3849.28    3849.28
# 2     2022-12-28  3829.56  3848.32  3780.78  3783.22    3783.22
# 3     2022-12-27  3843.34  3846.65  3813.22  3829.25    3829.25
# 4     2022-12-23  3815.11  3845.80  3797.01  3844.82    3844.82
# ...          ...      ...      ...      ...      ...        ...
# 1254  2018-01-08  2742.67  2748.51  2737.60  2747.71    2747.71
# 1255  2018-01-05  2731.33  2743.45  2727.92  2743.15    2743.15
# 1256  2018-01-04  2719.31  2729.29  2719.07  2723.99    2723.99
# 1257  2018-01-03  2697.85  2714.37  2697.77  2713.06    2713.06
# 1258  2018-01-02  2683.73  2695.89  2682.36  2695.81    2695.81
#
#              Volume    Name
# 0     2,979,870,000  S&P500
# 1     3,003,680,000  S&P500
# 2     3,083,520,000  S&P500
# 3     3,030,300,000  S&P500
# 4     2,819,280,000  S&P500
# ...

# %%
#plot the data to see it, sorted by date
sp500cleaned_df.sort_values(by = "Date", inplace = True)
sp500cleaned_df.plot(x="Date", y = "Close", figsize = (9,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Checking if S&P 500 is a stationary dataset

# %%
#making the date column in S&P500 as the index for plots
sp500cleaned_df.set_index("Date", inplace = True)

# %%
#creating function to check for p-value - which basically tells us whether or not if our dataset (specifically the close value)
#is stationary or not - stationary means the mean, variance and auto-regression does not change over time in a time-series model
from statsmodels.tsa.stattools import adfuller

def ad_test(dataset):
    dftest = adfuller(dataset, autolag = "AIC")
    print ("1. ADF: ", dftest[0])
    print ("2. P-value: ", dftest[1])
    print ("3. Number of lags: ", dftest[2])
    print ("4. Number of observations used for auto-regression model: ",dftest[3])
    for key, val in dftest[4].items():
        print("\t", key, ": ", val)

# %%
ad_test(sp500cleaned_df["Close"])
#ideally p-value should be <0.05 for stationary test, but we know our dataset is unpredictable but we just want to see if our
#machine learning model can predict prices or not
# Out:
# 1. ADF:  -1.235835175585013
# 2. P-value:  0.6579935568378482
# 3. Number of lags:  10
# 4. Number of observations used for auto-regression model:  1248
# 	 1% :  -3.4356006420838963
# 	 5% :  -2.8638586845641063
# 	 10% :  -2.5680044958343604

# %%
#Using ARIMA time series model as a starter model
from pmdarima import auto_arima

#ignore silly warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#try to find the best AIC score (the lower the better the model) - using S&P dataset
stepwise_fit = auto_arima(sp500cleaned_df["Close"], trace = True, suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=13079.672, Time=1.50 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=13147.765, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=13131.996, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=13133.985, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=13146.280, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=13131.387, Time=0.58 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=13131.767, Time=0.35 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=13081.108, Time=1.83 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=13133.896, Time=1.29 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=13131.047, Time=0.40 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=13132.092, Time=0.88 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=13133.017, Time=1.14 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=13083.027, Time=2.27 sec
# ...

# %% [markdown]
# #### Splitting the data into Training and Testing sets

# %%
#training the model
print(sp500cleaned_df.shape)
train = sp500cleaned_df.iloc[:-5] #we'll train the model on all data in dataset except the last 5 rows which will be used to test
test = sp500cleaned_df.iloc[-5:] #use last 5 datapoints to test model
print(train.shape, test.shape)
# Out:
# (1259, 7)
# (1254, 7) (5, 7)

# %% [markdown]
# #### Training the Model

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train["Close"], order=(2,1,2))
model = model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 1254
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -6509.103
# Date:                Mon, 30 Jan 2023   AIC                          13028.205
# Time:                        00:10:24   BIC                          13053.872
# Sample:                             0   HQIC                         13037.853
#                                - 1254
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.7546      0.027    -63.918      0.000      -1.808      -1.701
# ar.L2         -0.8802      0.026    -34.437      0.000      -0.930      -0.830
# ma.L1          1.6692      0.035     47.163      0.000       1.600       1.739
# ...

# %% [markdown]
# #### Making predictions on the test set

# %%
start = len(train)
end = len(train) + len(test) -1
pred = model.predict(start = start, end = end, typ = "levels")
#starting index start, ending index end (see index before, the last 5 datapoints used for test set)
pred.index = sp500cleaned_df.index[start:end+1]
print(pred)
# Out:
# Date
# 2022-12-23    3833.409825
# 2022-12-27    3827.335177
# 2022-12-28    3828.293696
# 2022-12-29    3831.959038
# 2022-12-30    3824.684054
# Name: predicted_mean, dtype: float64

# %%
#check actual vs prediction on last 5 datapoints (our test set)
pred.plot(legend = True, ylabel = "Close price")
test["Close"].plot(legend = True, figsize = (12,8))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close price'>

# %% [markdown]
# #### Checking for root mean squared error to see the difference between values predicted by the model

# %%
#checking for root mean square error to see the difference between values predicted by the model
#using sklearn module - importing needed libraries
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt (mean_squared_error(pred, test["Close"]))
print("Mean of test set: " ,test["Close"].mean())
print("Mean Squared Error: ", rmse)
# Out:
# Mean of test set:  3829.214
# Mean Squared Error:  23.173367098666617

# %% [markdown]
# The mean of the dataset and the mean squared errors are quite far apart, which means the model is acceptable. (Although pretty unpredictable as seen from previous chart, but still an okay model?) - if the mean squared error was close to the range of the mean of the test set, it would've been a bad model.

# %% [markdown]
# #### Making prediction on next 5 days (outside of dataset)

# %%
#fit model
model2 = ARIMA(sp500cleaned_df["Close"], order = (2,1,2))
model2 = model2.fit()
sp500cleaned_df.tail()
# Out:
#                Open     High      Low    Close  Adj_Close         Volume  \
# Date
# 2022-12-23  3815.11  3845.80  3797.01  3844.82    3844.82  2,819,280,000
# 2022-12-27  3843.34  3846.65  3813.22  3829.25    3829.25  3,030,300,000
# 2022-12-28  3829.56  3848.32  3780.78  3783.22    3783.22  3,083,520,000
# 2022-12-29  3805.45  3858.19  3805.45  3849.28    3849.28  3,003,680,000
# 2022-12-30  3829.06  3839.85  3800.34  3839.50    3839.50  2,979,870,000
#
#               Name
# Date
# 2022-12-23  S&P500
# 2022-12-27  S&P500
# 2022-12-28  S&P500
# 2022-12-29  S&P500
# 2022-12-30  S&P500

# %%
#make prediction on the next 7 days - so 2022-12-31 to 2023-01-06 (because 31,1 Dec are weekends and market is closed)
index_future_dates = pd.date_range(start = "2022-12-31", end = "2023-01-06") #basically assigning index to the prediction frame
pred = model2.predict(start = len(sp500cleaned_df), end = len(sp500cleaned_df) + 6, typ = "levels").rename("ARIMA Predictions")
pred.index = index_future_dates

#print(index_future_dates)
print(pred)
# Out:
# 2022-12-31    3852.035785
# 2023-01-01    3842.534031
# 2023-01-02    3848.172592
# 2023-01-03    3846.641003
# 2023-01-04    3844.367410
# 2023-01-05    3849.702423
# 2023-01-06    3842.345043
# Freq: D, Name: ARIMA Predictions, dtype: float64

# %%
pred.plot(figsize = (12,6), legend = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# One observation that's not taken into account by the model is that Dec 31, 2022 and Jan 1, 2023 were weekends. Based on the dataset for the s&p500, there are no datapoints for weekends, but we can still see an active close price for those 2 days.

# %% [markdown]
# ## Using the 5 crypto datasets to train, test, split our ML (time series) model

# %%
#create new datasets for each crypto to test if stationary or not
crypto_df.dropna()
ada_df = crypto_df[crypto_df["Name"] == "Cardano"]
bnb_df = crypto_df[crypto_df["Name"] == "Binance"]
btc_df = crypto_df[crypto_df["Name"] == "Bitcoin"]
doge_df = crypto_df[crypto_df["Name"] == "Dogecoin"]
eth_df = crypto_df[crypto_df["Name"] == "Ethereum"]

#eth_df.shape -all are(1826,8)
#ada_df.head()

# %% [markdown]
# #### Plotting some vizualizations

# %%
#plot the data to see it, sorted by date (ADA)
ada_df.sort_values(by = "Date", inplace = True)
ada_df.plot(x="Date", y = "Close", figsize = (9,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#plot the data to see it, sorted by date (BNB)
bnb_df.sort_values(by = "Date", inplace = True)
bnb_df.plot(x="Date", y = "Close", figsize = (9,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#plot the data to see it, sorted by date (BTC)
btc_df.sort_values(by = "Date", inplace = True)
btc_df.plot(x="Date", y = "Close", figsize = (9,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#plot the data to see it, sorted by date (DOGE)
doge_df.sort_values(by = "Date", inplace = True)
doge_df.plot(x="Date", y = "Close", figsize = (9,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#plot the data to see it, sorted by date (ETH)
#eth_df.sort_values(by = "Date", inplace = True)
#eth_df.plot(x="Date", y = "Close", figsize = (9,6))

# %%
#making the date column in S&P500 as the index for plots
ada_df.set_index("Date", inplace = True)
bnb_df.set_index("Date", inplace = True)
btc_df.set_index("Date", inplace = True)
doge_df.set_index("Date", inplace = True)
#eth_df.set_index("Date", inplace = True)

# %%
#ADA
print("ADA: ")
ad_test(ada_df["Close"]) #0.4155957134311176

#BNB
print("BNB: ")
ad_test(bnb_df["Close"]) #0.5242284936669828

#BTC
print("BTC: ")
ad_test(btc_df["Close"]) #0.62747613850301

#DOGECOIN
print("DOGE: ")
ad_test(doge_df["Close"]) #0.13027943130219544

#ETH - NAN exog error
#eth_df.dropna()
#print("ETH: ")
#ad_test(eth_df["Close"]) test
# Out:
# ADA:
# 1. ADF:  -1.7088388993389574
# 2. P-value:  0.42656426054316865
# 3. Number of lags:  22
# 4. Number of observations used for auto-regression model:  1803
# 	 1% :  -3.4339820768018106
# 	 5% :  -2.8631443597478143
# 	 10% :  -2.567624108684946
# BNB:
# 1. ADF:  -1.576130484827049
# 2. P-value:  0.4955718696493321
# 3. Number of lags:  25
# 4. Number of observations used for auto-regression model:  1800
# 	 1% :  -3.4339881389288407
# 	 5% :  -2.863147035877915
# 	 10% :  -2.567625533641975
# BTC:
# 1. ADF:  -1.3680900095432416
# 2. P-value:  0.5974750008160923
# 3. Number of lags:  24
# 4. Number of observations used for auto-regression model:  1801
# 	 1% :  -3.4339861159726306
# 	 5% :  -2.863146142843122
# 	 10% :  -2.5676250581282964
# DOGE:
# 1. ADF:  -2.4953830938569737
# 2. P-value:  0.11660171304496353
# 3. Number of lags:  25
# 4. Number of observations used for auto-regression model:  1800
# 	 1% :  -3.4339881389288407
# 	 5% :  -2.863147035877915
# ...

# %% [markdown]
# ETH dataset is giving me problems- but the other datasets, we notice the p-value are lower than the S&P500 data set, except BTC, which is pretty close with 0.62. (p-value for s&p was 0.65).

# %%
stepwise_fit_ada = auto_arima(ada_df["Close"], trace = True, suppress_warnings=True)
stepwise_fit_ada.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-5849.058, Time=1.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-5844.877, Time=0.34 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-5854.983, Time=0.84 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-5854.801, Time=0.67 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-5846.824, Time=0.18 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-5853.176, Time=0.43 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-5858.964, Time=0.99 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-5851.081, Time=0.75 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-5857.107, Time=1.40 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-5852.848, Time=0.65 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-5860.906, Time=0.41 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-5856.735, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-5856.918, Time=0.21 sec
# ...

# %%
stepwise_fit_bnb = auto_arima(bnb_df["Close"], trace = True, suppress_warnings=True)
stepwise_fit_bnb.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=14396.927, Time=1.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=14456.676, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=14423.137, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=14428.459, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=14454.869, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=14409.245, Time=0.60 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=14413.263, Time=0.81 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=14398.384, Time=2.06 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=14398.512, Time=2.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=14419.020, Time=0.62 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=14409.095, Time=1.23 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=14412.679, Time=0.64 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=14386.283, Time=2.84 sec
# ...

# %%
stepwise_fit_btc = auto_arima(btc_df["Close"], trace = True, suppress_warnings=True)
stepwise_fit_btc.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=30417.756, Time=2.63 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=30424.789, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=30425.617, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=30425.637, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=30422.794, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=30427.652, Time=0.27 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=30427.799, Time=1.23 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=30420.265, Time=3.61 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=30419.437, Time=3.07 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=30427.579, Time=0.74 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=30428.512, Time=0.88 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=30428.745, Time=0.72 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=30418.969, Time=3.62 sec
# ...

# %%
stepwise_fit_doge = auto_arima(doge_df["Close"], trace = True, suppress_warnings=True)
stepwise_fit_doge.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-10932.967, Time=2.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-10878.407, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-10906.464, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-10901.209, Time=0.64 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-10880.393, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-10927.195, Time=0.48 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-10918.269, Time=2.02 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-10948.472, Time=2.52 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-10925.266, Time=0.63 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-10970.929, Time=3.11 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-10923.566, Time=0.74 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=-11038.617, Time=4.44 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=-11034.260, Time=2.67 sec
# ...

# %%
#stepwise_fit_eth = auto_arima(eth_df["Close"], trace = True, suppress_warnings=True)
#stepwise_fit_eth.summary()

# %% [markdown]
# #### Splitting the data into Training and Testing sets

# %%
#training the model - same as we did for S&P500
print("ADA: ", ada_df.shape)
train_ada = ada_df.iloc[:-5] #we'll train the model on all data in dataset except the last 5 rows which will be used to test
test_ada = ada_df.iloc[-5:] #use last 5 datapoints to test model
print("ADA: ", train_ada.shape, test_ada.shape)

#BNB
print("BNB: ", bnb_df.shape)
train_bnb = bnb_df.iloc[:-5] #we'll train the model on all data in dataset except the last 5 rows which will be used to test
test_bnb = bnb_df.iloc[-5:] #use last 5 datapoints to test model
print("BNB: ", train_bnb.shape, test_bnb.shape)

#BTC
print("BTC: ", btc_df.shape)
train_btc = btc_df.iloc[:-5] #we'll train the model on all data in dataset except the last 5 rows which will be used to test
test_btc = btc_df.iloc[-5:] #use last 5 datapoints to test model
print("BTC: ", train_btc.shape, test_btc.shape)

#DOGE
print("DOGE: ", doge_df.shape)
train_doge = doge_df.iloc[:-5] #we'll train the model on all data in dataset except the last 5 rows which will be used to test
test_doge = doge_df.iloc[-5:] #use last 5 datapoints to test model
print("DOGE: ", train_doge.shape, test_doge.shape)

#ETH
#print("ETH: ", eth_df.shape)
#train_eth = eth_df.iloc[:-5] #we'll train the model on all data in dataset except the last 5 rows which will be used to test
#test_eth = eth_df.iloc[-5:] #use last 5 datapoints to test model
#print("ETH: ", train_rth.shape, test_eth.shape)
# Out:
# ADA:  (1826, 7)
# ADA:  (1821, 7) (5, 7)
# BNB:  (1826, 7)
# BNB:  (1821, 7) (5, 7)
# BTC:  (1826, 7)
# BTC:  (1821, 7) (5, 7)
# DOGE:  (1826, 7)
# DOGE:  (1821, 7) (5, 7)

# %% [markdown]
# #### Training the model on Crypto datasets

# %%
model_ada = ARIMA(train_ada["Close"], order=(1,1,1)) #using the AIC order computed previously (for best model fit)
model_ada = model_ada.fit()
model_ada.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 1821
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                2922.963
# Date:                Mon, 30 Jan 2023   AIC                          -5839.925
# Time:                        00:13:16   BIC                          -5823.406
# Sample:                    01-01-2018   HQIC                         -5833.831
#                          - 12-26-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7073      0.049    -14.371      0.000      -0.804      -0.611
# ma.L1          0.6367      0.053     11.985      0.000       0.533       0.741
# sigma2         0.0024    2.4e-05     98.085      0.000       0.002       0.002
# ...

# %%
model_bnb = ARIMA(train_bnb["Close"], order=(4,1,4)) #using the AIC order computed previously (for best model fit)
model_bnb = model_bnb.fit()
model_bnb.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 1821
# Model:                 ARIMA(4, 1, 4)   Log Likelihood               -7160.988
# Date:                Mon, 30 Jan 2023   AIC                          14339.976
# Time:                        00:13:19   BIC                          14389.535
# Sample:                    01-01-2018   HQIC                         14358.260
#                          - 12-26-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -2.0090      0.085    -23.587      0.000      -2.176      -1.842
# ar.L2         -2.1218      0.135    -15.668      0.000      -2.387      -1.856
# ar.L3         -1.4939      0.127    -11.765      0.000      -1.743      -1.245
# ...

# %%
model_btc = ARIMA(train_btc["Close"], order=(2,1,2)) #using the AIC order computed previously (for best model fit)
model_btc = model_btc.fit()
model_btc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 1821
# Model:                 ARIMA(2, 1, 2)   Log Likelihood              -15162.224
# Date:                Mon, 30 Jan 2023   AIC                          30334.448
# Time:                        00:13:20   BIC                          30361.981
# Sample:                    01-01-2018   HQIC                         30344.606
#                          - 12-26-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9305      0.010     97.276      0.000       0.912       0.949
# ar.L2         -0.9572      0.009   -101.124      0.000      -0.976      -0.939
# ma.L1         -0.9539      0.007   -141.213      0.000      -0.967      -0.941
# ...

# %%
model_doge = ARIMA(train_doge["Close"], order=(5,1,4)) #using the AIC order computed previously (for best model fit)
model_doge = model_doge.fit()
model_doge.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 1821
# Model:                 ARIMA(5, 1, 4)   Log Likelihood                5547.699
# Date:                Mon, 30 Jan 2023   AIC                         -11075.399
# Time:                        00:13:23   BIC                         -11020.333
# Sample:                    01-01-2018   HQIC                        -11055.083
#                          - 12-26-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1522      0.019      8.080      0.000       0.115       0.189
# ar.L2         -0.2623      0.021    -12.370      0.000      -0.304      -0.221
# ar.L3          0.2486      0.017     14.441      0.000       0.215       0.282
# ...

# %%
#model_eth = ARIMA(train_eth["Close"], order=(5,1,4)) #using the AIC order computed previously (for best model fit)
#model_eth = model_eth.fit()
#model_eth.summary()

# %% [markdown]
# #### Make predictions on the test sets

# %%
#ADA
start_ada = len(train_ada)
end_ada = len(train_ada) + len(test_ada) -1
pred_ada = model_ada.predict(start = start_ada, end = end_ada, typ = "levels")
#starting index start, ending index end (see index before, the last 5 datapoints used for test set)
pred_ada.index = ada_df.index[start_ada:end_ada + 1]
print(pred_ada)
# Out:
# Date
# 2022-12-27    0.264802
# 2022-12-28    0.265152
# 2022-12-29    0.264904
# 2022-12-30    0.265079
# 2022-12-31    0.264955
# Name: predicted_mean, dtype: float64

# %%
#check actual vs prediction on last 5 datapoints (our test set) - ADA
pred_ada.plot(legend = True, ylabel = "Close price")
test_ada["Close"].plot(legend = True, figsize = (12,8))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close price'>

# %%
#BNB
start_bnb = len(train_bnb)
end_bnb = len(train_bnb) + len(test_bnb) -1
pred_bnb = model_bnb.predict(start = start_bnb, end = end_bnb, typ = "levels")
#starting index start, ending index end (see index before, the last 5 datapoints used for test set)
pred_bnb.index = bnb_df.index[start_bnb:end_bnb + 1]
print(pred_bnb)
# Out:
# Date
# 2022-12-27    243.988856
# 2022-12-28    245.229669
# 2022-12-29    243.657248
# 2022-12-30    244.143076
# 2022-12-31    244.764399
# Name: predicted_mean, dtype: float64

# %%
#check actual vs prediction on last 5 datapoints (our test set) - BNB
pred_bnb.plot(legend = True, ylabel = "Close price")
test_bnb["Close"].plot(legend = True, figsize = (12,8))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close price'>

# %%
#BTC
start_btc = len(train_btc)
end_btc = len(train_btc) + len(test_btc) -1
pred_btc = model_btc.predict(start = start_btc, end = end_btc, typ = "levels")
#starting index start, ending index end (see index before, the last 5 datapoints used for test set)
pred_btc.index = btc_df.index[start_btc:end_btc + 1]
print(pred_btc)
# Out:
# Date
# 2022-12-27    16977.685934
# 2022-12-28    16998.033322
# 2022-12-29    16961.556043
# 2022-12-30    16908.138179
# 2022-12-31    16893.351634
# Name: predicted_mean, dtype: float64

# %%
#check actual vs prediction on last 5 datapoints (our test set) - BTC
pred_btc.plot(legend = True, ylabel = "Close price")
test_btc["Close"].plot(legend = True, figsize = (12,8))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close price'>

# %%
#DOGE
start_doge = len(train_doge)
end_doge = len(train_doge) + len(test_doge) -1
pred_doge = model_doge.predict(start = start_doge, end = end_doge, typ = "levels")
#starting index start, ending index end (see index before, the last 5 datapoints used for test set)
pred_doge.index = doge_df.index[start_doge:end_doge + 1]
print(pred_doge)
# Out:
# Date
# 2022-12-27    0.075777
# 2022-12-28    0.074517
# 2022-12-29    0.074361
# 2022-12-30    0.075241
# 2022-12-31    0.075158
# Name: predicted_mean, dtype: float64

# %%
#check actual vs prediction on last 5 datapoints (our test set) - DOGE
pred_doge.plot(legend = True, ylabel = "Close price")
test_doge["Close"].plot(legend = True, figsize = (12,8))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close price'>

# %%
#ETH
#start_eth = len(train_eth)
#end_eth = len(train_eth) + len(test_eth) -1
#pred_eth = model_eth.predict(start = start_eth, end = end_eth, typ = "levels")
#starting index start, ending index end (see index before, the last 5 datapoints used for test set)
#pred_eth.index = eth_df.index[start_eth:end_eth + 1]
#print(pred_eth)

# %%
#check actual vs prediction on last 5 datapoints (our test set) - ETH
#pred_eth.plot(legend = True, ylabel = "Close price")
#test_eth["Close"].plot(legend = True, figsize = (12,8))

# %% [markdown]
# #### Checking for root mean squared error to see the difference between values predicted by the model

# %%
#checking for root mean square error to see the difference between values predicted by the model
rmse_ada = sqrt(mean_squared_error(pred_ada, test_ada["Close"]))
print("Mean of ADA test set: " ,test_ada["Close"].mean())
print("Mean Squared Error: ", rmse_ada)
print(" ")

rmse_bnb = sqrt(mean_squared_error(pred_bnb, test_bnb["Close"]))
print("Mean of BNB test set: " ,test_bnb["Close"].mean())
print("Mean Squared Error: ", rmse_bnb)
print(" ")

rmse_btc = sqrt(mean_squared_error(pred_btc, test_btc["Close"]))
print("Mean of BTC test set: " ,test_btc["Close"].mean())
print("Mean Squared Error: ", rmse_btc)
print(" ")

rmse_doge = sqrt(mean_squared_error(pred_doge, test_doge["Close"]))
print("Mean of DOGE test set: " ,test_doge["Close"].mean())
print("Mean Squared Error: ", rmse_doge)
print(" ")

#rmse_eth = sqrt(mean_squared_error(pred_eth, test_eth["Close"]))
#print("Mean of ETH test set: " ,test_eth["Close"].mean())
#print("Mean Squared Error: ", rmse_eth)
# Out:
# Mean of ADA test set:  0.24898220000000001
# Mean Squared Error:  0.017059538338748258
#
# Mean of BNB test set:  245.86999999999998
# Mean Squared Error:  2.057524491627722
#
# Mean of BTC test set:  16612.434
# Mean Squared Error:  340.9334385980009
#
# Mean of DOGE test set:  0.070769
# Mean Squared Error:  0.004533187331952508
